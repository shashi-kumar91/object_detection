# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 882.8/882.8 kB 14.6 MB/s eta 0:00:00
# ...

# %%
# Import the YOLO class from the ultralytics package
from ultralytics import YOLO

# Load a YOLOv8 model (using the nano version for speed)
model = YOLO('yolov8n.pt')  # You can choose 'yolov8s.pt' for small, 'yolov8l.pt' for large, etc.

# Train the model
model.train(
    data='/content/drive/MyDrive/Dataset/data.yaml',  # Path to your data.yaml file
    epochs=50,                                        # Number of epochs to train for
    imgsz=640,                                       # Image size (you can adjust this based on your system)
    batch=16,                                        # Batch size (you can adjust this based on your GPU memory)
    save=True                                        # Save the model after training
)

# Optional: Evaluate the model after training
metrics = model.val()
# Out:
# Ultralytics 8.3.5 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
metrics = model.val()  # This will run validation on the dataset and output metrics like mAP, precision, and recall
# Out:
# Ultralytics 8.3.5 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/drive/MyDrive/Dataset/valid/labels.cache... 320 images, 33 backgrounds, 0 corrupt: 100%|██████████| 340/340 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 22/22 [00:07<00:00,  2.82it/s]
#                    all        340        557      0.897      0.905      0.908      0.687
#                   bike         29         29      0.838      0.828       0.83      0.569
#               motobike         26         26      0.824          1      0.925      0.719
#                 person         64         71       0.92      0.978      0.942      0.695
#    traffic_light_green         59         59      0.947      0.915      0.958      0.616
#   traffic_light_orange         24         24      0.836      0.852      0.859      0.501
# ...

# %%
results = model.predict(source='/content/drive/MyDrive/Dataset/test/images/1004_jpg.rf.8993d602c9a9b9bde6e32cb27d99007d.jpg')
# Out:
# image 1/1 /content/drive/MyDrive/Dataset/test/images/1004_jpg.rf.8993d602c9a9b9bde6e32cb27d99007d.jpg: 640x640 1 traffic_light_green, 14.2ms
# Speed: 6.2ms preprocess, 14.2ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt

# Run the model on the image
results = model.predict(source='/content/drive/MyDrive/Dataset/test/images/1004_jpg.rf.8993d602c9a9b9bde6e32cb27d99007d.jpg')

# Plot the image with predictions
plt.imshow(results[0].plot())  # results[0] gives the first image result, and .plot() draws the boxes and labels
plt.axis('off')  # Hide axis
plt.show()  # Display the image
# Out:
# image 1/1 /content/drive/MyDrive/Dataset/test/images/1004_jpg.rf.8993d602c9a9b9bde6e32cb27d99007d.jpg: 640x640 1 traffic_light_green, 58.0ms
# Speed: 3.9ms preprocess, 58.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt

# Path to your test image
image_path = '/content/drive/MyDrive/Dataset/test/images/122_jpg.rf.d51cc655cd78a11249f3af8b8766b0f7.jpg'

# Run the model prediction on the image
results = model.predict(source=image_path)

# Plot and visualize the image with predictions (bounding boxes, labels)
plt.imshow(results[0].plot())  # results[0] refers to the first image in the batch (if there's only one image)
plt.axis('off')  # Hide axis
plt.show()  # Display the image with predictions
# Out:
# image 1/1 /content/drive/MyDrive/Dataset/test/images/122_jpg.rf.d51cc655cd78a11249f3af8b8766b0f7.jpg: 640x640 1 motobike, 7.6ms
# Speed: 2.9ms preprocess, 7.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt

# Path to your test image
image_path = '/content/drive/MyDrive/Dataset/test/images/1441_jpg.rf.94acdf421c63e4bb8702389b256957fb.jpg'

# Run the model prediction on the image
results = model.predict(source=image_path)

# Plot and visualize the image with predictions (bounding boxes, labels)
plt.imshow(results[0].plot())  # results[0] refers to the first image in the batch (if there's only one image)
plt.axis('off')  # Hide axis
plt.show()  # Display the image with predictions
# Out:
# image 1/1 /content/drive/MyDrive/Dataset/test/images/1441_jpg.rf.94acdf421c63e4bb8702389b256957fb.jpg: 640x640 1 person, 20.8ms
# Speed: 7.1ms preprocess, 20.8ms inference, 3.2ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt

# Path to your test image
image_path = '/content/drive/MyDrive/Dataset/test/images/906_jpg.rf.8c384bca5eca41e56a592f23ec84e85e.jpg'

# Run the model prediction on the image
results = model.predict(source=image_path)

# Plot and visualize the image with predictions (bounding boxes, labels)
plt.imshow(results[0].plot())  # results[0] refers to the first image in the batch (if there's only one image)
plt.axis('off')  # Hide axis
plt.show()  # Display the image with predictions
# Out:
# image 1/1 /content/drive/MyDrive/Dataset/test/images/906_jpg.rf.8c384bca5eca41e56a592f23ec84e85e.jpg: 640x640 1 traffic_sign_30, 13.1ms
# Speed: 4.1ms preprocess, 13.1ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt

# Path to your test image
image_path = '/content/drive/MyDrive/Dataset/test/images/842_jpg.rf.f0bd941a288c243be3fc5b6a66c34eb0.jpg'

# Run the model prediction on the image
results = model.predict(source=image_path)

# Plot and visualize the image with predictions (bounding boxes, labels)
plt.imshow(results[0].plot())  # results[0] refers to the first image in the batch (if there's only one image)
plt.axis('off')  # Hide axis
plt.show()  # Display the image with predictions
# Out:
# image 1/1 /content/drive/MyDrive/Dataset/test/images/842_jpg.rf.f0bd941a288c243be3fc5b6a66c34eb0.jpg: 640x640 1 person, 1 traffic_light_red, 38.3ms
# Speed: 4.4ms preprocess, 38.3ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt

# Path to your test image
image_path = '/content/drive/MyDrive/Dataset/test/images/82_jpg.rf.71f824e04c286a259071a8fefffd2b72.jpg'

# Run the model prediction on the image
results = model.predict(source=image_path)

# Plot and visualize the image with predictions (bounding boxes, labels)
plt.imshow(results[0].plot())  # results[0] refers to the first image in the batch (if there's only one image)
plt.axis('off')  # Hide axis
plt.show()  # Display the image with predictions
# Out:
# image 1/1 /content/drive/MyDrive/Dataset/test/images/82_jpg.rf.71f824e04c286a259071a8fefffd2b72.jpg: 640x640 1 bike, 1 traffic_sign_60, 1 vehicle, 13.6ms
# Speed: 8.7ms preprocess, 13.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 640)
